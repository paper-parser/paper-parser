# %% [markdown]
# ## Notes
#
# Use `new_env` (not the best name, oh well) to run this notebook due to Python 3.6 dependencies.

# %%
! which python
# Out:
# /home/christinehc/anaconda3/envs/py36/bin/python

# %%
! python -V
# Out:
# Python 3.6.8 :: Anaconda, Inc.

# %% [markdown]
# ## Initialization

# %%
import io

from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage

# %% [markdown]
# ## Testing

# %%
def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = io.StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos = set()

    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages,
                                  password=password,
                                  caching=caching,
                                  check_extractable=True):
        interpreter.process_page(page)

    text = retstr.getvalue()

    fp.close()
    device.close()
    retstr.close()
    return text

# %% [markdown]
# PDF document can be downloaded from the link on Slack; I used the Angewandte paper because it is shorter.  Change pathlength to match where to find the pdf in your local directory.

# %%
f = open('angew.txt','w')
f.write(convert_pdf_to_txt('/home/christinehc/downloads/anie.201406466.pdf'))
f.close()

# %%
with open('angew.txt') as f:
    read_data = f.read()
    
read_data
# Out:
# 'Angewandte\n\n.\n\nCommunications\n\nPerovskite Solar Cells\n\nDOI: 10.1002/anie.201406466\n\nA Layered Hybrid Perovskite Solar-Cell Absorber with Enhanced\nMoisture Stability**\nIan C. Smith, Eric T. Hoke, Diego Solis-Ibarra, Michael D. McGehee, and\nHemamala I. Karunadasa*\n\nAbstract: Two-dimensional hybrid perovskites are used as\nabsorbers in solar cells. Our first-generation devices containing\n(PEA)2(MA)2[Pb3I10] (1; PEA = C6H5(CH2)2NH3\n+, MA =\nCH3NH3\n+) show an open-circuit voltage of 1.18 V and\na power conversion efficiency of 4.73 %. The layered structure\nallows for high-quality films to be deposited through spin\ncoating and high-temperature annealing is not required for\ndevice fabrication. The 3D perovskite (MA)[PbI3] (2) has\nrecently been identified as a promising absorber for solar cells.\nHowever, its instability to moisture requires anhydrous proc-\nessing and operating conditions. Films of 1 are more moisture\nresistant than films of 2 and devices containing 1 can be\nfabricated under ambient humidity levels. The larger bandgap\nof the 2D structure is also suitable as the higher bandgap\nabsorber in a dual-absorber tandem device. Compared to 2, the\nlayered perovskite structure may offer greater tunability at the\nmolecular level for material optimization.\n\nThree-dimensional (3D) hybrid perovskites of the form\n(MA)[PbX3] (MA = CH3NH3\n+; X = Cl, Br, or I) have recently\nemerged as promising absorbers for solar cells.[1] The first\nreported perovskite solar cell with (MA)[PbI3] showed\na power conversion efficiency (PCE) of 3.81 %.[1a] Rapid\nmaterial and device optimization has led to PCEs exceeding\n15 % in just a few years.[2] Though progress in device\nefficiencies has been remarkable, the lead–halide perovskites\nhave two main drawbacks: the toxicity of the water-soluble\nsource of\nto\natmospheric moisture. Recently, the lead perovskite was\nreplaced by the significantly less toxic tin analogue in solar\ncells with efficiencies of up to approximately 6 %.[3] However,\nthe moisture sensitivity of the lead perovskite has not yet\nbeen addressed. Motivated by our observations that the\nstructurally related two-dimensional (2D) perovskites readily\nformed high-quality films that appeared more resistant to\nhumidity than the 3D analogues, we sought to assess if the\n\nlead and the instability of\n\nthe material\n\n[*] I. C. Smith, Dr. D. Solis-Ibarra, Prof. H. I. Karunadasa\n\nDepartment of Chemistry, Stanford University\nStanford, CA 94305 (USA)\nE-mail: hemamala@stanford.edu\nDr. E. T. Hoke, Prof. M. D. McGehee\nDepartment of Materials Science and Engineering\nStanford University, Stanford, CA 94305 (USA)\n\n[**] This research was funded by the Global Climate and Energy Project.\n\nX-ray diffraction studies were performed at the Stanford Nano-\ncharacterization Laboratory. We thank William Nguyen and Greyson\nChristoforo for experimental assistance.\nSupporting information for this article is available on the WWW\nunder http://dx.doi.org/10.1002/anie.201406466.\n\nlayered materials could function as solar-cell absorbers.\nHerein, we report the structure of the layered perovskite\n(PEA)2(MA)2[Pb3I10] (1; PEA = C6H5(CH2)2NH3\n+) that can\nact as an absorber in a solar cell with an open-circuit voltage\nof 1.18 V and a PCE of 4.73 %. Although our first-generation\ndevices have lower efficiencies than current solar cells with\n3D perovskite absorbers, the layered structure brings distinct\nadvantages. In contrast to (MA)[PbI3] (2), high-quality films\nof 1 can be obtained through one-step spin coating under\nambient conditions without annealing. Films of 1 are also\nmore resistant to moisture compared to 2, and devices\ncontaining 1 can be fabricated under humid conditions.\nImportantly, the layered structure affords greater tunability,\nwhich may provide additional routes for material optimiza-\ntion.\n\nLayered perovskites can be structurally derived from the\n3D analogue by slicing along specific\n ...

# %% [markdown]
# ## ChemDataExtractor

# %%
from chemdataextractor import Document

# %%
doc = Document(read_data)

# %%
doc.cems
# Out:
# [Span('(MA)[PbI3]', 13804, 13814),
#  Span('Cl', 1354, 1356),
#  Span('S', 20156, 20157),
#  Span('TiO2', 10382, 10386),
#  Span('nitromethane', 5138, 5150),
#  Span('Pb', 15615, 15617),
#  Span('perovskite (PEA)2(MA)2[Pb3I10]', 6022, 6052),
#  Span('perovskite', 2022, 2032),
#  Span('PEA', 411, 414),
#  Span('perovskite', 17252, 17262),
#  Span('perovskites', 15412, 15423),
#  Span('perovskite (MA)[PbI3]', 5965, 5986),
#  Span('Br', 1358, 1360),
#  Span('PbI2', 14454, 14458),
#  Span('perovskite', 1843, 1853),
#  Span('Pb–I perovskites', 15485, 15501),
#  Span('perovskite', 1452, 1462),
#  Span('C6H5(CH2)2NH3', 3117, 3130),
#  Span('H', 20885, 20886),
#  Span('perovskites', 15775, 15786),
#  Span('3 lead perovskite', 5252, 5269),
#  Span('Pb', 5007, 5009),
#  Span('CA 94305', 2600, 2608),
#  Span('H', 17878, 17879),
#  Span('H', 20250, 20251),
#  Span('H', 20239, 20240),
#  Span('N,N-dimethylformamide', 9585, 9606),
#  Span('perovskites', 297, 308),
#  Span('N = blue', 6280, 6288),
#  Span('perovskite', 1168, 1178),
#  Span('PbCl2', 10208, 10213),
#  Span('PbCl2', 13864, 13869),
#  Span('(PEA)2(MA)2[Pb3I10]', 14152, 14171),
#  Span('halide', 4160, 4166),
#  Span('(MA)[PbX3]', 1323, 1333),
#  Span('(MA)[PbI3]', 3420, 3430),
#  Span('PbI2', 9656, 9660),
#  Span('perovskite', 7658, 7668),
#  Span('2,2’,7,-\n7’-tetrakis-(N,N-di-p-methoxyphenylamine)-9,9’-spirobifluor-\nene (spiro-OMeTAD)', 9432, 9520),
#  Span('Noh', 20242, 20245),
#  Span('perovskite', 10114, 10124),
#  Span('(MA)[PbI3]', 1479, 1489),
#  Span('acetone', 5151, 5158),
#  Span('fluorocarbons', 16821, 16834),
#  Span('perovskite', 3333, 3343),
#  Span('perovskites', 4092, 4103),
#  Span('CH3NH3', 439, 445),
#  Span('Lumin', 18869, 18874),
#  Span('PbI2', 14556, 14560),
#  Span('perovskites', 1299, 1310),
#  Span('H', 19854, 19855),
#  Span('halide', 1711, 1717),
#  Span('N', 18641, 18642),
#  Span('Pb', 6252, 6254),
#  Span('TiO2', 9389, 9393),
#  Span('PbI2', 5077, 5081),
#  Span('N', 18252, 18253),
#  Span('perovskite (MA)[PbI3]', 700, 721),
#  Span('(PEA)2(MA)2', 8151, 8162),
#  Span('perovskites', 1718, 1729),
#  Span('Pb–I perovskite', 15120, 15135),
#  Span('Li', 19741, 19743),
#  Span('Solis', 2347, 2352),
#  Span('CA 94305', 2440, 2448),
#  Span('H', 17539, 17540),
#  Span('tin', 1899, 1902),
#  Span('(MA)[PbI3]', 14177, 14187),
#  Span('Christoforo', 2817, 2828),
#  Span('PEA', 6205, 6208),
#  Span('Br', 15618, 15620),
#  Span('perovskite', 9204, 9214),
#  Span('(PEA)2(MA)2[Pb3I10]', 10868, 10887),
#  Span('H', 19021, 19022),
#  Span('H', 2367, 2368),
#  Span('perovskites', 9110, 9121),
#  Span('PEA', 3111, 3114),
#  Span('perovskite\n(PEA)2(MA)2[Pb3I10]', 3076, 3106),
#  Span('perovskites', 15362, 15373),
#  Span('H', 19966, 19967),
#  Span('H', 20582, 20583),
#  Span('N', 18781, 18782),
#  Span('perovskites', 15621, 15632),
#  Span('(PEA)2(MA)2[Pb3I10]', 387, 406),
#  Span('(PEA)2(MA)2[Pb3I10]', 5176, 5195),
#  Span('PbCl2', 14239, 14244),
#  Span('H', 20136, 20137),
#  Span('CH3NH3', 1340, 1346),
#  Span('Solis', 201, 206),
#  Span('C6H5(CH2)2NH3', 417, 430),
#  Span('(MA)[PbI3]', 14216, 14226),
#  Span('spiro-OMeTAD', 10391, 10403),
#  Span('Perovskite', 101, 111),
#  Span('perovskites', 2142, 2153),
#  Span('Perovskite', 31, 41),
#  Span('perovskites', 3816, 3827),
#  Span('PbI2', 14200, 14204),
#  Span('hydrogens', 6321, 6330),
#  Span('perovskite', 15181, 15191)]

# %%
doc.abbreviation_definitions
# Out:
# [(['PCE'], ['power', 'conversion', 'efficiency'], None),
#  (['USA'], ['University', 'Stanford', ',', 'CA', '94305'], None),
#  (['USA'], ['University', ',', 'Stanford', ',', 'CA', '94305'], None),
#  (['PXRD'], ['Powder', 'X-ray', 'diffraction'], None),
#  (['PXRD'], ['Powder', 'X-ray', 'diffraction'], None),
#  (['SEM'], ['scanning', 'electron', 'microscopy'], None),
#  (['EQE'], ['external', 'quantum', 'efficiency'], None)]

# %%
doc.records
# Out:
# [<Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>, <Compound>]

# %% [markdown]
# Testing ChemDataExtractor's native PDF reader:

# %%
f = open('/home/christinehc/downloads/anie.201406466.pdf', 'rb')
docpdf = Document.from_file(f)
f.close()

# %%
docpdf
# Out:
# <Document: 93 elements>

# %%
docpdf.cems
# Out:
# [Span('H', 17, 18),
#  Span('hydrogens', 398, 407),
#  Span('Solis', 117, 122),
#  Span('Perovskite', 17, 27),
#  Span('Lumin', 20, 25),
#  Span('perovskites', 33, 44),
#  Span('perovskites', 873, 884),
#  Span('perovskite', 904, 914),
#  Span('(PEA)2(MA)2[Pb3I10]', 84, 103),
#  Span('Li', 8, 10),
#  Span('Pb', 1199, 1201),
#  Span('CH3NH3', 71, 77),
#  Span('PbCl2', 701, 706),
#  Span('S', 246, 247),
#  Span('perovskites', 30, 41),
#  Span('(MA)[PbI3]', 61, 71),
#  Span('nitromethane', 1330, 1342),
#  Span('(MA)[PbI3]', 449, 459),
#  Span('(MA)[PbI3]', 641, 651),
#  Span('PbI2', 338, 342),
#  Span('perovskite', 51, 61),
#  Span('(MA)[PbI3]', 100, 110),
#  Span('(PEA)2(MA)2[Pb3I10]', 36, 55),
#  Span('perovskite', 525, 535),
#  Span('Perovskite', 0, 10),
#  Span('CH3NH3', 175, 181),
#  Span('PbI2', 95, 99),
#  Span('Pb–I perovskite', 23, 38),
#  Span('halide', 352, 358),
#  Span('H', 59, 60),
#  Span('Br', 279, 281),
#  Span('.Keywords', 0, 9),
#  Span('PEA', 140, 143),
#  Span('perovskite', 835, 845),
#  Span('spiro-OMeTAD', 1065, 1077),
#  Span('tin', 630, 633),
#  Span('H', 241, 242),
#  Span('Pb', 329, 331),
#  Span('acetone', 1343, 1350),
#  Span('PEA', 282, 285),
#  Span('perovskite\n(PEA)2(MA)2[Pb3I10]', 105, 135),
#  Span('perovskite', 574, 584),
#  Span('Solis', 24, 29),
#  Span('N', 37, 38),
#  Span('perovskites', 73, 84),
#  Span('H', 156, 157),
#  Span('N,N-dimethylformamide', 259, 280),
#  Span('perovskites', 282, 293),
#  Span('H', 44, 45),
#  Span('(PEA)2(MA)2[Pb3I10]', 123, 142),
#  Span('H', 226, 227),
#  Span('halide', 442, 448),
#  Span('PbCl2', 123, 128),
#  Span('PbI2', 1269, 1273),
#  Span('N', 114, 115),
#  Span('PEA', 147, 150),
#  Span('Br', 89, 91),
#  Span('perovskite', 753, 763),
#  Span('TiO2', 63, 67),
#  Span('(MA)[PbI3]', 210, 220),
#  Span('perovskites', 436, 447),
#  Span('H', 19, 20),
#  Span('perovskites', 449, 460),
#  Span('PbI2', 84, 88),
#  Span('perovskite (MA)[PbI3]', 42, 63),
#  Span('perovskites', 8, 19),
#  Span('PbI2', 330, 334),
#  Span('PbCl2', 882, 887),
#  Span('perovskite', 84, 94),
#  Span('perovskite', 788, 798),
#  Span('N', 207, 208),
#  Span('H', 31, 32),
#  Span('perovskite', 183, 193),
#  Span('(PEA)2(MA)2', 54, 65),
#  Span('perovskites', 23, 34),
#  Span('C6H5(CH2)2NH3', 153, 166),
#  Span('(MA)[PbX3]', 54, 64),
#  Span('I. Karunadasa', 47, 60),
#  Span('CA 94305', 55, 63),
#  Span('CA 94305', 215, 223),
#  Span('Noh', 11, 14),
#  Span('perovskite (PEA)2(MA)2[Pb3I10]', 99, 129),
#  Span('perovskite (MA)[PbI3]', 436, 457),
#  Span('C6H5(CH2)2NH3', 146, 159),
#  Span('N = blue', 357, 365),
#  Span('2,2’,7,-\n7’-tetrakis-(N,N-di-p-methoxyphenylamine)-9,9’-spirobifluor-\nene (spiro-OMeTAD)', 106, 194),
#  Span('Pb', 276, 278),
#  Span('H', 56, 57),
#  Span('H', 8, 9),
#  Span('3 lead perovskite', 1444, 1461),
#  Span('perovskites', 284, 295),
#  Span('Christoforo', 128, 139),
#  Span('TiO2', 1056, 1060),
#  Span('Cl', 85, 87),
#  Span('fluorocarbons', 867, 880),
#  Span('perovskites', 741, 752),
#  Span('Pb–I perovskites', 146, 162),
#  Span('perovskite', 362, 372),
#  Span('(PEA)2(MA)2[Pb3I10]', 1368, 1387),
#  Span('H', 244, 245)]

# %%
doc.records[0].serialize()
# Out:
# {'names': ['(MA)[PbX3]']}

# %%
doc.records.serialize()
# Out:
# [{'names': ['(MA)[PbX3]']},
#  {'names': ['Cl']},
#  {'names': ['tin']},
#  {'names': ['Christoforo']},
#  {'names': ['nitromethane']},
#  {'names': ['acetone']},
#  {'names': ['3 lead perovskite']},
#  {'names': ['N = blue']},
#  {'names': ['hydrogens']},
#  {'names': ['(PEA)2(MA)2-']},
#  {'names': ['2,2’,7,- 7’-tetrakis-(N,N-di-p-methoxyphenylamine)-9,9’-spirobifluor- ene ( spiro-OMeTAD )']},
#  {'names': ['N,N-dimethylformamide']},
#  {'names': ['spiro-OMeTAD']},
#  {'names': ['Pb–I perovskite']},
#  {'names': ['Pb–I perovskites']},
#  {'names': ['fluorocarbons']},
#  {'names': ['Lumin']},
#  {'names': ['Li']},
#  {'names': ['S']},
#  {'names': ['Noh']},
#  {'names': ['Solis']},
#  {'names': ['C6H5(CH2)2NH3']},
#  {'names': ['CH3NH3']},
#  {'names': ['Br']},
#  {'names': ['halide']},
#  {'names': ['CA 94305', 'USA']},
#  {'names': ['PEA']},
#  {'names': ['TiO2']},
#  {'names': ['PbCl2']},
#  {'names': ['Pb']},
#  {'names': ['N']},
#  {'names': ['perovskite (MA)[PbI3]', '(MA)[PbI3]'], 'labels': ['2']},
#  {'names': ['(PEA)2(MA)2[Pb3I10]', 'perovskite (PEA)2(MA)2[Pb3I10]'],
#   'labels': ['1']},
#  {'names': ['PbI2']},
#  {'names': ['perovskites']},
#  {'names': ['perovskite', 'Perovskite']},
#  {'names': ['H']}]

# %%
docpdf.records.serialize()
# Out:
# [{'names': ['(MA)[PbX3]']},
#  {'names': ['Cl']},
#  {'names': ['tin']},
#  {'names': ['I. Karunadasa']},
#  {'names': ['Christoforo']},
#  {'names': ['nitromethane']},
#  {'names': ['acetone']},
#  {'names': ['3 lead perovskite']},
#  {'names': ['N = blue']},
#  {'names': ['hydrogens']},
#  {'names': ['(PEA)2(MA)2-']},
#  {'names': ['2,2’,7,- 7’-tetrakis-(N,N-di-p-methoxyphenylamine)-9,9’-spirobifluor- ene ( spiro-OMeTAD )']},
#  {'names': ['N,N-dimethylformamide']},
#  {'names': ['spiro-OMeTAD']},
#  {'names': ['Pb–I perovskite']},
#  {'names': ['Pb–I perovskites']},
#  {'names': ['fluorocarbons']},
#  {'names': ['.Keywords']},
#  {'names': ['Lumin']},
#  {'names': ['Li']},
#  {'names': ['S']},
#  {'names': ['Noh']},
#  {'names': ['Solis']},
#  {'names': ['C6H5(CH2)2NH3']},
#  {'names': ['CH3NH3']},
#  {'names': ['Br']},
#  {'names': ['halide']},
#  {'names': ['CA 94305', 'USA']},
#  {'names': ['PEA']},
#  {'names': ['TiO2']},
#  {'names': ['PbCl2']},
#  {'names': ['Pb']},
#  {'names': ['N']},
#  {'names': ['perovskite (MA)[PbI3]', '(MA)[PbI3]'], 'labels': ['2']},
#  {'names': ['(PEA)2(MA)2[Pb3I10]', 'perovskite (PEA)2(MA)2[Pb3I10]'],
#   'labels': ['1']},
#  {'names': ['PbI2']},
#  {'names': ['perovskites']},
#  {'names': ['perovskite', 'Perovskite']},
#  {'names': ['H']}]

# %%
docpdf.elements
# Out:
# [Paragraph(id=None, references=[], text='Angewandte'),
#  Paragraph(id=None, references=[], text='.'),
#  Paragraph(id=None, references=[], text='Communications'),
#  Paragraph(id=None, references=[], text='Perovskite Solar Cells'),
#  Paragraph(id=None, references=[], text='DOI: 10.1002/anie.201406466'),
#  Paragraph(id=None, references=[], text='A Layered Hybrid Perovskite Solar-Cell Absorber with Enhanced\nMoisture Stability**\nIan C. Smith, Eric T. Hoke, Diego Solis-Ibarra, Michael D. McGehee, and\nHemamala I. Karunadasa*'),
#  Paragraph(id=None, references=[], text='Abstract: Two-dimensional hybrid perovskites are used as\nabsorbers in solar cells. Our first-generation devices containing\n(PEA)2(MA)2[Pb3I10] (1; PEA = C6H5(CH2)2NH3\n+, MA =\nCH3NH3\n+) show an open-circuit voltage of 1.18 V and\na power conversion efficiency of 4.73 %. The layered structure\nallows for high-quality films to be deposited through spin\ncoating and high-temperature annealing is not required for\ndevice fabrication. The 3D perovskite (MA)[PbI3] (2) has\nrecently been identified as a promising absorber for solar cells.\nHowever, its instability to moisture requires anhydrous proc-\nessing and operating conditions. Films of 1 are more moisture\nresistant than films of 2 and devices containing 1 can be\nfabricated under ambient humidity levels. The larger bandgap\nof the 2D structure is also suitable as the higher bandgap\nabsorber in a dual-absorber tandem device. Compared to 2, the\nlayered perovskite structure may offer greater tunability at the\nmolecular level for material optimization.'),
#  Paragraph(id=None, references=[], text='Three-dimensional (3D) hybrid perovskites of the form\n(MA)[PbX3] (MA = CH3NH3\n+; X = Cl, Br, or I) have recently\nemerged as promising absorbers for solar cells.[1] The first\nreported perovskite solar cell with (MA)[PbI3] showed\na power conversion efficiency (PCE) of 3.81 %.[1a] Rapid\nmaterial and device optimization has led to PCEs exceeding\n15 % in just a few years.[2] Though progress in device\nefficiencies has been remarkable, the lead–halide perovskites\nhave two main drawbacks: the toxicity of the water-soluble\nsource of\nto\natmospheric moisture. Recently, the lead perovskite was\nreplaced by the significantly less toxic tin analogue in solar\ncells with efficiencies of up to approximately 6 %.[3] However,\nthe moisture sensitivity of the lead perovskite has not yet\nbeen addressed. Motivated by our observations that the\nstructurally related two-dimensional (2D) perovskites readily\nformed high-quality films that appeared more resistant to\nhumidity than the 3D analogues, we sought to assess if the'),
#  Paragraph(id=None, references=[], text='lead and the instability of'),
#  Paragraph(id=None, references=[], text='the material'),
#  Paragraph(id=None, references=[], text='[*] I. C. Smith, Dr. D. Solis-Ibarra, Prof. H. I. Karunadasa'),
#  Paragraph(id=None, references=[], text='Department of Chemistry, Stanford University\nStanford, CA 94305 (USA)\nE-mail: hemamala@stanford.edu\nDr. E. T. Hoke, Prof. M. D. McGehee\nDepartment of Materials Science and Engineering\nStanford University, Stanford, CA 94305 (USA)'),
#  Paragraph(id=None, references=[], text='[**] This research was funded by the Global Climate and Energy Project.'),
#  Paragraph(id=None, references=[], text='X-ray diffraction studies were performed at the Stanford Nano-\ncharacterization Laboratory. We thank William Nguyen and Greyson\nChristoforo for experimental assistance.\nSupporting information for this article is available on the WWW\nunder http://dx.doi.org/10.1002/anie.201406466.'),
#  Paragraph(id=None, references=[], text='layered materials could function as solar-cell absorbers.\nHerein, we report the structure of the layered perovskite\n(PEA)2(MA)2[Pb3I10] (1; PEA = C6H5(CH2)2NH3\n+) that can\nact as an absorber in a solar cell with an open-circuit voltage\nof 1.18 V and a PCE of 4.73 %. Although our first-generation\ndevices have lower efficiencies than current solar cells with\n3D perovskite absorbers, the layered structure brings distinct\nadvantages. In contrast to (MA)[PbI3] (2), high-quality films\nof 1 can be obtained through one-step spin coating under\nambient conditions without annealing. Films of 1 are also\nmore resistant to moisture compared to 2, and devices\ncontaining 1 can be fabricated under humid conditions.\nImportantly, the layered structure affords greater tunability,\nwhich may provide additional routes for material optimiza-\ntion.'),
#  Paragraph(id=None, references=[], text='Layered perovskites can be structurally derived from the\n3D analogue by slicing along specific\ncrystallographic\nplanes.[4] The interlayer separation and thickness of the\ninorganic layers can be controlled through the choice of\norganic cations.[5] The inorganic layers of most\nlayered\nperovskites comprise a single sheet (n = 1) of corner-sharing\nmetal–halide octahedra sandwiching layers of organic cat-\nions.[4] These 2D materials do not have electronic properties\ntypically associated with good solar-cell absorbers. Along with\nlarger bandgaps compared to the 3D analogue (n =1), the\nspatial confinement of the 2D structure and dielectric mis-\nmatch between organic and inorganic layers lead to strongly\nbound excitons with low mobility.[6] Such tightly bound\nexcitons are difficult to dissociate into free carriers at room\ntemperature and the localized charge carriers are unlikely to\nreach the electron/hole selective contacts in a typical solar-\ncell geometry. To access the more favorable electronic\nproperties of the 3D structure, we sought an intermediate\nstructure between the n = 1 and n =1 materials. We synthe-\nsized the n = 3 member of the series (PEA)2(MA)n\x001[PbnI3n+1]\n(n = number of Pb–I sheets in each inorganic layer), by\ncombining (PEA)I, (MA)I, and PbI2 in a 2:2:3 stoichiometric\nratio in a solvent mixture of nitromethane/acetone. Slow\nsolvent\nof\n(PEA)2(MA)2[Pb3I10] (1), the first crystallographically char-\nacterized n = 3 lead perovskite (Figure 1).'),
#  Paragraph(id=None, references=[], text='evaporation'),
#  Paragraph(id=None, references=[], text='afforded'),
#  Paragraph(id=None, references=[], text='dark'),
#  Paragraph(id=None, references=[], text='red'),
#  Paragraph(id=None, references=[], text='crystals'),
#  Paragraph(id=None, references=[], text='Decreasing the dimensionality of the inorganic compo-\nnents from the 3D structure causes an increase in the bandgap\nand the exciton binding energy. The reported n = 1 and 2\nstructures have bandgaps of 2.57 and 2.32 eV, respectively,\nand exciton absorption bands at 2.35 and 2.15 eV, respec-\ntively.[7] Their exciton binding energies can be estimated as\nthe difference between bandgap and exciton absorption\nenergies to be 220 and 170 meV for the n = 1 and 2 structures,'),
#  Paragraph(id=None, references=[], text='11232'),
#  Paragraph(id=None, references=[], text='\x17 2014 Wiley-VCH Verlag GmbH & Co. KGaA, Weinheim'),
#  Paragraph(id=None, references=[], text='Angew. Chem. Int. Ed. 2014, 53, 11232 –11235'),
#  Paragraph(id=None, references=[], text='Angewandte'),
#  Paragraph(id=None, references=[], text='Chemie'),
#  Paragraph(id=None, references=[], text='Figure 1. A) Crystal structures of the 3D perovskite (MA)[PbI3] (2, from\nRef. [12a]) and B) the 2D perovskite (PEA)2(MA)2[Pb3I10] (1). The\ninorganic layers in 1 can be structurally derived from 2 by slicing along\nspecific crystallographic planes (turquoise sheets in (A)). Inset: a PEA\ncation in the organic layers. Atom colors: Pb = turquoise; I = purple;\nN = blue; C = gray. Disordered atoms and hydrogens omitted for\nclarity.'),
#  Paragraph(id=None, references=[], text='respectively.[7] Absorbance measurements of 1 show the\nexciton band at 2.06 eV, which lies close to an estimated\nbandgap of approximately 2.1 eV, indicating that the exciton\nbinding energy is significantly smaller and close to the value\nof 2 (circa 40 meV).[6] The bandgap of 1 is larger than that of 2\n(1.61 eV)[8] and larger than the ideal value of 1.34 eV\ncalculated by Shockley and Queisser for the highest efficiency\nobtainable by a single-junction solar cell (circa 34 %).[9]\nHowever, 1 can absorb a significant fraction of the solar\nspectrum to afford a theoretical PCE of approximately 20 %.\nThe bandgap of 1 is also close to the ideal value (1.9 eV) for\nthe higher bandgap absorber in a dual-absorber tandem\ndevice,[10] which can exceed the Shockley-Queisser limit.[11]'),
#  Paragraph(id=None, references=[], text='High-quality films of 1 can be deposited from precursor\nsolutions through one-step spin coating. Similar processing of\n2 does not afford continuous films (see Figure S1 in the\nSupporting Information). The layered structure of 1 likely\naids film formation: unlike 2 that crystallizes as rhombic\ndodecahedra at room temperature,[12] 1 forms plates (Fig-\nure S2). Powder X-ray diffraction (PXRD) patterns of films\nof 1 show reflections indicating a preferential orientation of\ncrystallites (Figure 2, top). To confirm the n = 3 perovskite\nstructure in these films, we scraped the films into a powder,\nloaded it into a glass capillary, and obtained unoriented\nPXRD patterns (Figure 2, middle). These unoriented PXRD\ndata show the reflections calculated from the single-crystal X-\nray structure of 1 (Figure 2, bottom). The absorption spec-\ntrum of films of 1 shows exciton absorption bands at 2.06, 2.19,\nand 2.41 eV (Figure S4). We assign the peak at 2.06 eV to the'),
#  Paragraph(id=None, references=[], text='Figure 2. Powder X-ray diffraction (PXRD) patterns of (PEA)2(MA)2-\n[Pb3I10] (1) as an oriented film (top) and as powder scraped from\na film and measured in a glass capillary (middle), and the calculated\nPXRD pattern from the single-crystal X-ray structure of 1 (bottom).'),
#  Paragraph(id=None, references=[], text='n = 3 material. The peaks at 2.19 and 2.41 eV match the\nexciton absorption energies of the n = 2 and n = 1 structures,\nrespectively.[5c,13] These phases are not visible in the PXRD\npatterns of films of 1, suggesting defect layers of less than n =\n3 within the structure. Small amounts of n = 1 and 2 phases\ncan show in the absorption spectrum because of the high\noscillator strength of excitons in these materials.[13] Slight\nshoulders at 1.94 and 1.87 eV may be caused by trace amounts\nof n = 4 and 5 phases, respectively. The absorption spectrum\ndoes not show peaks corresponding to 2 (Figure S4). When\nexcited at 2.54 eV, the emission spectrum of 1 shows a peak at\n1.68 eV (Figure S5). This energy lies between the emission\nmaxima for 2D perovskites with lower values of n (n = 1 at\n2.36 eV[13] and n = 2 at 2.15 eV[14]) and the 3D perovskite (n =\n1 at 1.58 eV). A weak emission at 2.36 eV is likely because of\nphotoluminescence (PL) from n = 1 layers.'),
#  Paragraph(id=None, references=[], text='Devices utilizing 1 as the absorber were constructed\nemploying TiO2 as the electron-selective contact and 2,2’,7,-\n7’-tetrakis-(N,N-di-p-methoxyphenylamine)-9,9’-spirobifluor-\nene (spiro-OMeTAD) as the hole-selective contact. Films of\n1 were deposited from a N,N-dimethylformamide solution\ncontaining stoichiometric quantities of PbI2, (MA)I, and\n(PEA)I using a single spin-coating step. Importantly, devices\ncontaining 1 can be processed in humid air, which does not\naffect film quality or device performance. In contrast, devices\nwith 2 must be processed under low-humidity levels for\noptimal performance. High-quality films of 2 also require\nhigh-temperature thermal evaporation[2b] or multistep depo-\nsition methods, such as heat-assisted conversion of spin-\ncoated PbI2 films to the perovskite through exposure to\n(MA)I solution[15] or vapor,[2a] or simultaneous deposition of\nPbCl2 and (MA)I and high-temperature annealing.[16] A\nscanning electron microscopy (SEM) image of a fully con-\nstructed device is shown in Figure 3 A. Typical thicknesses of\nTiO2, 1, spiro-OMeTAD, and gold layers are 50, 425, 125, and\n75 nm, respectively. We obtained current–voltage (JV) curves\nof these devices using simulated AM1.5G solar illumination\n(Figure 3 B). The open-circuit voltages (Voc) for these devices'),
#  Paragraph(id=None, references=[], text='Angew. Chem. Int. Ed. 2014, 53, 11232 –11235'),
#  Paragraph(id=None, references=[], text='\x17 2014 Wiley-VCH Verlag GmbH & Co. KGaA, Weinheim'),
#  Paragraph(id=None, references=[], text='www.angewandte.org'),
#  Paragraph(id=None, references=[], text='11233'),
#  Paragraph(id=None, references=[], text='Angewandte'),
#  Paragraph(id=None, references=[], text='.'),
#  Paragraph(id=None, references=[], text='Communications'),
#  Paragraph(id=None, references=[], text='Figure 3. A) SEM cross section and device configuration of planar\ndevices utilizing (PEA)2(MA)2[Pb3I10] (1) as the absorber layer. Scale\nbar = 500 nm. B) Current–voltage (JV) curves for the devices fabricated\nas given in (A).'),
#  Paragraph(id=None, references=[], text='routinely exceed 1.0 V; the best device shows a value of\n1.18 V. Owing to the larger bandgap of the 2D material, these\nVoc values are higher than for cells containing 2 (highest\nreported Voc = 0.924–1.07 V).[2a–c, 15] The increase in Voc value\nof approximately 0.1 eV correlates well with the measured\n0.1 eV increase in the peak PL energy (Figure S5), indicating\nthat carriers are extracted from the same energy levels where\nradiative recombination occurs.'),
#  Paragraph(id=None, references=[], text='The JV curve characteristics of these devices are sensitive\nto measurement speed. Faster scan rates afforded a maximum\ncurrent density of 11.53 mA cm\x002, a Voc value of 1.21 V, and\na PCE of 7.02 %, but the forward and reverse scans showed\na large hysteresis (Figure S8). Similar effects have been\ndetected in thin-film devices with 2.[17] To minimize these\neffects, the current densities were measured at each voltage\nafter a delay period (70 s) to allow the current to approach\nsteady-state conditions (Figure S9). Even at this slow mea-\nsurement rate, there is a slight overestimation of photocurrent\nnear the maximum-power point as a result of slow, capacitive\neffects. We therefore fit the data to the characteristic solar-cell\nequation (Figure S9) in order to obtain more reliable values\nof 0.60 for the fill factor (FF) and 4.73 % for the PCE. The\ncurrent density under\nis\n6.72 mA cm\x002. The external quantum efficiency (EQE) spec-\ntrum matches the profile of the absorption spectrum of\n1 (Figure S10). The integrated current\nfrom the EQE\nspectrum yields a net current density of 7.47 mA cm\x002,\ncorroborating the Jsc value obtained through steady-state\nmeasurements. We calculate an internal quantum efficiency\nof 70 %, assuming 10 % parasitic absorbance by non-absorber'),
#  Paragraph(id=None, references=[], text='short-circuit'),
#  Paragraph(id=None, references=[], text='conditions'),
#  Paragraph(id=None, references=[], text='(Jsc)'),
#  Paragraph(id=None, references=[], text='components of the device. This indicates that charge extrac-\ntion could be limited, caused likely by the layered structure of\n1, which has no direct path between adjacent inorganic layers.\nLow-dimensional inorganic materials have previously been\neffectively used in photovoltaic devices,[18] and device opti-\nmization should afford improvements in Jsc values and overall\nefficiency.'),
#  Paragraph(id=None, references=[], text='Upon exposure to ambient humidity at room temperature,\nopaque black films of 2 convert into a translucent yellow\nsolid.[12b, 19] Finished devices containing 2 can be encapsulated\nto avoid exposure to water. However, inherent stability to\nmoisture will likely be necessary for large-scale manufacture\nor for achieving the long lifetimes required for broad\ncommercialization. To compare the stability of 1 and 2 to\nmoisture, we exposed spin-coated films of both materials to\nhumidity-controlled environments. Because direct spin coat-\ning results in poor-quality, discontinuous films of 2 (denoted\n2 a), we also formed higher-quality films of (MA)[PbI3]\n(denoted 2 b) by depositing a 1:3 molar ratio of PbCl2:(MA)I\nand annealing the films at 100 8C.[16] All films were exposed to\na relative humidity level of 52 % for up to approximately\n40 days and their PXRD patterns were periodically recorded\n(Figure 4). Upon humidity exposure, the PXRD patterns of'),
#  Paragraph(id=None, references=[], text='Figure 4. PXRD patterns of films of (PEA)2(MA)2[Pb3I10] (1), (MA)[PbI3]\nformed from PbI2 (2 a), and (MA)[PbI3] formed from PbCl2 (2 b), which\nwere exposed to 52 % relative humidity. Annealing of films of 2 a\n(15 minutes) and 2 b (80 minutes) was conducted at 100 8C prior to\nhumidity exposure. Asterisks denote the major reflections from PbI2.'),
#  Paragraph(id=None, references=[], text='2 a and 2 b show a new phase after circa 4–5 days, which can be\nindexed to the PXRD pattern of PbI2 (Figure S11). These new\nreflections completely dominate the PXRD patterns after\napproximately 40 days. Absorption spectra of 2 a and 2 b show\na decrease in absorbance near the bandgap and an increase in\nabsorbance above 2.4 eV (Figures S12 and 13) as the higher-\nbandgap PbI2 phase grows as yellow patches on the films\n(Figure S14). In contrast, the PXRD pattern of 1 does not\nshow additional reflections over a period of 46 days of\nhumidity exposure and the absorption spectra show no\nsignificant changes over this time (Figure S15).'),
#  Paragraph(id=None, references=[], text='We show that a layered Pb–I perovskite can act as a solar-\ncell absorber. The n = 3 perovskite takes an intermediate'),
#  Paragraph(id=None, references=[], text='11234 www.angewandte.org'),
#  Paragraph(id=None, references=[], text='\x17 2014 Wiley-VCH Verlag GmbH & Co. KGaA, Weinheim'),
#  Paragraph(id=None, references=[], text='Angew. Chem. Int. Ed. 2014, 53, 11232 –11235'),
#  Paragraph(id=None, references=[], text='position between n = 1 perovskites with strongly bound\nexcitons and n =1 perovskites with weakly bound excitons.\nStrongly bound excitons in n = 1 Pb–I perovskites lead to\ngreen PL,[20] and green electroluminescence,[14, 21] and we\nrecently reported on broadband white PL from Pb–Br\nperovskites.[22] In contrast, weakly bound excitons and shallow\ntrap states could contribute to the unusually long carrier\ndiffusion lengths seen in n =1 perovskites.[23] These dramatic\nchanges in electronic properties as a function of the structural\nevolution from n = 1 to n =1 are of both fundamental and\ntechnological interest.'),
#  Paragraph(id=None, references=[], text='Solar cells containing 1 display PCEs up to 4.73 %.\nThough devices containing 2 have exceeded PCEs of\n15 %,[2a–c] their moisture sensitivity remains a concern for\nlarge-scale device fabrication or their long-term use. The\nlayered structure of 1 aids the formation of high-quality films\nthat show greater moisture resistance compared to 2. The\nlarger bandgap of 1 also affords a higher VOC value of 1.18 V\ncompared to devices with 2. Further improvements in\nmaterial structure and device engineering, including making\nappropriate electronic contact with the anisotropic inorganic\nsheets, should increase the PCEs of\nthese devices. In\nparticular, higher values of n as single-phase materials or as\nmixtures may allow for lower bandgaps and higher carrier\nmobility in the inorganic layers while the organic layers\nprovide additional\ntunability. For example, hydrophobic\nfluorocarbons could increase moisture stability, conjugated\norganic layers could facilitate charge transport, and organic\nphotosensitizers could improve the absorption properties of\nthe material. We are focused on manipulating this extraordi-\nnarily versatile platform through synthetic design.'),
#  Paragraph(id=None, references=[], text='Received: June 22, 2014\nRevised: July 30, 2014\nPublished online: September 1, 2014'),
#  Paragraph(id=None, references=[], text='.Keywords: layered compounds · materials science · perovskite ·'),
#  Paragraph(id=None, references=[], text='photovoltaics · solar cells'),
#  Paragraph(id=None, references=[], text='[1] a) A. Kojima, K. Teshima, Y. Shirai, T. Miyasaka, J. Am. Chem.\nSoc. 2009, 131, 6050 – 6051; b) J.-H. Im, C.-R. Lee, J.-W. Lee, S.-\nW. Park, N.-G. Park, Nanoscale 2011, 3, 4088 – 4093; c) M. M.\nLee, J. Teuscher, T. Miyasaka, T. N. Murakami, H. J. Snaith,\nScience 2012, 338, 643 – 647; d) L. Etgar, P. Gao, Z. Xue, Q. Peng,\nA. K. Chandiran, B. Liu, M. K. Nazeeruddin, M. Grätzel, J. Am.\nChem. Soc. 2012, 134, 17396 – 17399.'),
#  Paragraph(id=None, references=[], text='[2] a) J. Burschka, N. Pellet, S.-J. Moon, R. Humphry-Baker, P. Gao,\nM. K. Nazeeruddin, M. Grätzel, Nature 2013, 499, 316 – 319;\nb) M. Liu, M. B. Johnston, H. J. Snaith, Nature 2013, 501, 395 –'),
#  Paragraph(id=None, references=[], text='Angewandte'),
#  Paragraph(id=None, references=[], text='Chemie'),
#  Paragraph(id=None, references=[], text='398; c) D. Liu, T. L. Kelly, Nat. Photonics 2014, 8, 133 – 138; d) S.\nKazim, M. K. Nazeeruddin, M. Grätzel, S. Ahmad, Angew.\nChem. Int. Ed. 2014, 53, 2812 – 2824; Angew. Chem. 2014, 126,\n2854 – 2867.'),
#  Paragraph(id=None, references=[], text='[3] a) F. Hao, C. C. Stoumpos, D. H. Cao, R. P. H. Chang, M. G.\nKanatzidis, Nat. Photonics 2014, 8, 489 – 494; b) N. K. Noel,\net al., Energy Environ. Sci. 2014, 7, 3061 – 3068.'),
#  Paragraph(id=None, references=[], text='[4] a) D. B. Mitzi, Prog. Inorg. Chem. 1999, 48, 1 – 121; b) D. B.'),
#  Paragraph(id=None, references=[], text='Mitzi, J. Chem. Soc. Dalton Trans. 2001, 1 – 12.'),
#  Paragraph(id=None, references=[], text='[5] a) D. B. Mitzi, C. A. Feild, W. T. A. Harrison, A. M. Guloy,\nNature 1994, 369, 467 – 469; b) D. B. Mitzi, S. Wang, C. A. Feild,\nC. A. Chess, A. M. Guloy, Science 1995, 267, 1473 – 1476; c) J.\nCalabrese, N. L. Jones, R. L. Harlow, N. Herron, D. L. Thorn, Y.\nWang, J. Am. Chem. Soc. 1991, 113, 2328 – 2330.'),
#  Paragraph(id=None, references=[], text='[6] E. A. Muljarov, S. G. Tikhodeev, N. A. Gippius, T. Ishihara,'),
#  Paragraph(id=None, references=[], text='Phys. Rev. B 1995, 51, 14370 – 14378.'),
#  Paragraph(id=None, references=[], text='[7] T. Ishihara, J. Lumin. 1994, 60 – 61, 269 – 274.\n[8] Y. Yasuhiro, N. Toru, E. Masaru, W. Atsushi, K. Yoshihiko, Appl.'),
#  Paragraph(id=None, references=[], text='Phys. Express 2014, 7, 032302.'),
#  Paragraph(id=None, references=[], text='[9] W. Shockley, H. J. Queisser, J. Appl. Phys. 1961, 32, 510 – 519.\n[10] A. D. Vos, J. Phys. D 1980, 13, 839 – 846.\n[11] a) A. S. Brown, M. A. Green, Physica E 2002, 14, 96 – 100;\nb) Z. M. Beiley, M. D. McGehee, Energy Environ. Sci. 2012, 5,\n9173 – 9179.'),
#  Paragraph(id=None, references=[], text='[12] a) C. C. Stoumpos, C. D. Malliakas, M. G. Kanatzidis, Inorg.\nChem. 2013, 52, 9019 – 9038; b) T. Baikie, Y. Fang, J. M. Kadro,\nM. Schreyer, F. Wei, S. G. Mhaisalkar, M. Graetzel, T. J. White, J.\nMater. Chem. A 2013, 1, 5628 – 5641.'),
#  Paragraph(id=None, references=[], text='[13] X. Hong, T. Ishihara, A. V. Nurmikko, Phys. Rev. B 1992, 45,'),
#  Paragraph(id=None, references=[], text='6961 – 6964.'),
#  Paragraph(id=None, references=[], text='[14] X. Hong, T. Ishihara, A. V. Nurmikko, Solid State Commun.'),
#  Paragraph(id=None, references=[], text='1992, 84, 657 – 661.'),
#  Paragraph(id=None, references=[], text='[15] Q. Chen, H. Zhou, Z. Hong, S. Luo, H.-S. Duan, H.-H. Wang, Y.'),
#  Paragraph(id=None, references=[], text='Liu, G. Li, Y. Yang, J. Am. Chem. Soc. 2014, 136, 622 – 625.'),
#  Paragraph(id=None, references=[], text='[16] G. E. Eperon, V. M. Burlakov, P. Docampo, A. Goriely, H. J.'),
#  Paragraph(id=None, references=[], text='Snaith, Adv. Funct. Mater. 2014, 24, 151 – 157.'),
#  Paragraph(id=None, references=[], text='et al., J. Phys. Chem. Lett. 2014, 5, 1511 – 1515.\n[17] H. J. Snaith,\n[18] a) T. T. Ngo, S. Chavhan, I. Kosta, O. Miguel, H.-J. Grande, R.\nTena-Zaera, ACS Appl. Mater. Interfaces 2014, 6, 2836 – 2841;\nb) M. Calixto-Rodriguez, H. M. García, M. T. S. Nair, P. K. Nair,\nECS J. Solid State Sci. Technol. 2013, 2, Q69 – Q73.'),
#  Paragraph(id=None, references=[], text='[19] J. H. Noh, S. H. Im, J. H. Heo, T. N. Mandal, S. I. Seok, Nano'),
#  Paragraph(id=None, references=[], text='Lett. 2013, 13, 1764 – 1769.'),
#  Paragraph(id=None, references=[], text='[20] K. Gauthron, et al., Opt. Express 2010, 18, 5912 – 5919.\n[21] a) M. Era, S. Morimoto, T. Tsutsui, S. Saito, Appl. Phys. Lett.\n1994, 65, 676 – 678; b) K. Chondroudis, D. B. Mitzi, Chem. Mater.\n1999, 11, 3028 – 3030.'),
#  Paragraph(id=None, references=[], text='[22] E. R. Dohner, E. T. Hoke, H. I. Karunadasa, J. Am. Chem. Soc.'),
#  Paragraph(id=None, references=[], text='2014, 136, 1718 – 1721.'),
#  Paragraph(id=None, references=[], text='[23] a) G. Xing, N. Mathews, S. Sun, S. S. Lim, Y. M. Lam, M. Grätzel,\nS. Mhaisalkar, T. C. Sum, Science 2013, 342, 344 – 347; b) S. D.\nStranks, G. E. Eperon, G. Grancini, C. Menelaou, M. J. P.\nAlcocer, T. Leijtens, L. M. Herz, A. Petrozza, H. J. Snaith,\nScience 2013, 342, 341 – 344.'),
#  Paragraph(id=None, references=[], text='Angew. Chem. Int. Ed. 2014, 53, 11232 –11235'),
#  Paragraph(id=None, references=[], text='\x17 2014 Wiley-VCH Verlag GmbH & Co. KGaA, Weinheim'),
#  Paragraph(id=None, references=[], text='www.angewandte.org'),
#  Paragraph(id=None, references=[], text='11235')]

# %% [markdown]
# Stolen from CDE's documentation; haven't played around with in any capacity

# %%
# Define a very basic entity tagger
specifier = (I('PCEs') + I('temperature') + Optional(lrb | delim) + Optional(R('^T(C|c)(urie)?')) 
             + Optional(rrb) | R('^T(C|c)(urie)?'))('specifier').add_action(join)
units = (R('^[CFK]\.?$'))('units').add_action(merge)
value = (R('^\d+(\.\,\d+)?$'))('value')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-6aac836ef896> in <module>
#       1 # Define a very basic entity tagger
#       2 specifier = (I('PCEs') + I('temperature') + Optional(lrb | delim) + Optional(R('^T(C|c)(urie)?'))
# ----> 3              + Optional(rrb) | R('^T(C|c)(urie)?'))('specifier').add_action(join)
#       4 units = (R('^[CFK]\.?$'))('units').add_action(merge)
#       5 value = (R('^\d+(\.\,\d+)?$'))('value')
#
# NameError: name 'I' is not defined
