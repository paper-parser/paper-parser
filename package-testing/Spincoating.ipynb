# %% [markdown]
# ## Initialization

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import spacy
import logging
import re

from lxml.builder import E

from chemdataextractor import Document
from chemdataextractor.model import Compound, BaseModel, StringType, ListType, ModelType
from chemdataextractor.doc import Paragraph, Heading
from chemdataextractor.utils import first
from chemdataextractor.parse.elements import W, I, T, R, Optional, ZeroOrMore, OneOrMore, Not
from chemdataextractor.parse.cem import chemical_name
from chemdataextractor.parse.base import BaseParser
from chemdataextractor.parse.actions import join, merge, strip_stop
from chemdataextractor.parse.common import hyphen

# %%
E?

# %% [markdown]
# `.parse`:
#
# * `R(pattern)`: match token text with regular expression
# * `I(match)`: case-insensitive match token text
# * `W(match)`: match token text exactly
# * `T(match)`: match tag exactly
# * `Optional(expr)`: abstract class for combining and post-processing parsed tokens
# * `merge(tokens, start, result)`: join tokens into a single string with no spaces
# * `ZeroOrMore(expr)`: optional repetition of zero or more of the given expression
# * `OneOrMore(expr)`: repetition of one or more of the given expression
# * `Not(expr):` check ahead to disallow a match with the given parse expression

# %%
nlp = spacy.load('en_core_web_sm') # Load English dictionary from spaCy

# %% [markdown]
# ## Importing test synthesis paragraph and sentence

# %%
# Nature Materials
ptext = u"A dense blocking layer of TiO2 (bl-TiO2, ∼70 nm in thickness) was deposited onto a F-doped SnO2 (FTO, Pilkington, TEC8) substrate by spray pyrolysis, using a 20 mM titanium diisopropoxide bis(acetylacetonate) solution (Aldrich) at 450 °C to prevent direct contact between the FTO and the hole-conducting layer. A 200–300-nm-thick mesoporous TiO2 (particle size: about 50 nm, crystalline phase: anatase) film was spin-coated onto the bl-TiO2/FTO substrate using home-made pastes14 and calcining at 500 °C for 1 h in air to remove organic components. CH3NH3I (MAI) and CH3NH3Br (MABr) were first synthesized by reacting 27.86 ml CH3NH2 (40% in methanol, Junsei Chemical) and 30 ml HI (57 wt% in water, Aldrich) or 44 ml HBr (48 wt% in water, Aldrich) in a 250 ml round-bottom flask at 0 °C for 4 h with stirring, respectively. The precipitate was recovered by evaporation at 55 °C for 1 h. MAI and MABr were dissolved in ethanol, recrystallized from diethyl ether, and dried at 60 °C in a vacuum oven for 24 h. The prepared MAI and MABr powders, PbI2 (Aldrich) and PbBr2 (Aldrich) for 0.8 M MAPb(I1 − xBrx)3 (x  =  0.1–0.15) solution were stirred in a mixture of GBL and DMSO (7:3 v/v) at 60 °C for 12 h. The resulting solution was coated onto the mp-TiO2/bl-TiO2/FTO substrate by a consecutive two-step spin-coating process at 1,000 and 5,000 r.p.m for 10 and 20 s, respectively. During the second spin-coating step, the substrate (around 1 cm × 1 cm) was treated with toluene drop-casting. A detailed time-rotation profile for the spin-coating is represented in Supplementary Fig. 1c. The substrate was dried on a hot plate at 100 °C for 10 min. A solution of poly(triarylamine) (15 mg, PTAA, EM Index, Mw  =  17,500 g mol−1) in toluene (1.5 ml) was mixed with 15 μl of a solution of lithium bistrifluoromethanesulphonimidate (170 mg) in acetonitrile (1 ml) and 7.5 μl 4-tert-butylpyridine and spin-coated on the MAPb(I1 − xBrx)3 (x  =  0.1–0.15)/mp-TiO2/bl-TiO2/FTO substrate at 3,000 r.p.m for 30 s. Finally, a Au counterelectrode was deposited by thermal evaporation. The active area of this electrode was fixed at 0.16 cm2."

# %%
# Formatting the Nature Nanotech paragraph according to ChemDataExtractor
p = Document(Heading(u'Solar cell fabrication'), Paragraph(ptext))

# %%
# Sentence version
s = Document(u'The resulting solution was coated onto the mp-TiO2/bl-TiO2/FTO substrate by a consecutive two-step spin-coating process at 1,000 and 5,000 r.p.m for 10 and 20 s, respectively.')

# %%
p
# Out:
# <Document: 2 elements>

# %%
s
# Out:
# <Document: 1 elements>

# %% [markdown]
# ### Outlining Spincoat Parameter Extraction
#
#     {'Synthesis' : {
#                 'spincoat' : {
#                     'time' : {
#                         'value' : (number),
#                         'units' : 's',
#                         },
#                     },
#                 'anneal' : {
#                     'time' : {
#                         'value' : (number),
#                         'units' : 's',
#                         },
#                     'temperature' : {
#                         'value' : (number),
#                         'units' : 'K',
#                         },
#                 etc...
#     }
#
# Structuring my code to fit the format:
#
#     create 'spincoat' class to parse spincoat spds
#     spincoat: (value) (units)
#         create 'time' subclass in the spincoat class
#         time: (value) (units)
#     create 'anneal' class to parse annealing conditions
#         create 'time' subclass in the anneal class
#         time: (value) (units)
#         create 'temperature' subclass in the anneal class
#         temperature: (value) (units)

# %%
# Parsing spin-coating speed
class SpinSpd(BaseModel):
    value = StringType()
    units = StringType()
    
Compound.spin_spd = ListType(ModelType(SpinSpd))

# Extracting units (may not be strictly next to the value)
def extract_units(tokens, start, result):
    """Extract units from bracketed after nu"""
    for e in result:
        for child in e.iter():
            # Tags units as units (e.g. <unit>rpm</unit>)
            if R(u'^\b?r(\.)?p(\.)?m(\.)?\b?$') in child.text:
                return [E('units', 'rpm')]
            elif R(u'^r(\.)?c(\.)?f(\.)?$') in child.text:
                return [E('units', 'rcf')]
            elif R(u'^([x×]?)(\s?)?g$') in child.text:
                return [E('units', 'g')]
    return []

# %%
# Adding GBL to the solvents list
gbl_solvent = (I('GBL') | R('γ-[Bb]utyrolactone') | chemical_name('solvent'))
solvent = (gbl_solvent | chemical_name)('solvent').add_action(join)

# Defining formats for value and units
units = (R(u'^\b?r(\.)?p(\.)?m(\.)?\b?$') | R(u'^r(\.)?c(\.)?f(\.)?$') | R(u'^([x×]?)(\s?)?g$'))(u'units') + Optional(W(')')).hide())
#Optional(W('/')).hide() + W(u'^r\.?p\.?m\.?')
#R('^(re)?crystalli[sz](ation|ed)$', re.I)
value = R(u'^\d+(,\d+)?$')(u'value')
spinspd = (value + units)(u'spinspd')

class SpinSpdParser(BaseParser):
    root = spinspd

    def interpret(self, result, start, end):
        compound = Compound(
            spin_spd=[
                SpinSpd(
                    solvent=first(result.xpath('./solvent/text()')),
                    value=first(result.xpath('./value/text()')),
                    units=first(result.xpath('./units/text()'))
                )
            ]
        )
        yield compound

# %%
Paragraph.parsers = [SpinSpdParser()]

# %%
d = Document(u'The resulting solution was coated onto the mp-TiO2/bl-TiO2/FTO substrate by a consecutive two-step spin-coating process at 1,000 and 5,000 r.p.m for 10 and 20 s, respectively.')

d.records.serialize()
# Out:
# [{'spin_coat_spd': [{'value': '1,000'}]},
#  {'spin_coat_spd': [{'value': '5,000'}]},
#  {'spin_coat_spd': [{'value': '10'}]},
#  {'spin_coat_spd': [{'value': '20'}]}]

# %%
sp_nm = nlp(ptext)

for token in sp_nm:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
          token.shape_, token.is_alpha, token.is_stop)
# Out:
# A a DET DT det X True False
# dense dense ADJ JJ amod xxxx True False
# blocking block VERB VBG amod xxxx True False
# layer layer NOUN NN nsubjpass xxxx True False
# of of ADP IN prep xx True True
# TiO2 tio2 PROPN NNP pobj XxXd False False
# ( ( PUNCT -LRB- punct ( False False
# bl bl NUM CD compound xx True False
# - - PUNCT : punct - False False
# TiO2 tio2 PROPN NNP punct XxXd False False
# , , PUNCT , punct , False False
# ∼70 ∼70 VERB VB det ∼dd False False
# nm nm NUM CD appos xx True False
# in in ADP IN prep xx True True
# thickness thickness NOUN NN pobj xxxx True False
# ) ) PUNCT -RRB- punct ) False False
# was be VERB VBD auxpass xxx True True
# deposited deposit VERB VBN ROOT xxxx True False
# onto onto ADP IN prep xxxx True True
# a a DET DT det x True True
# F f PROPN NNP npadvmod X True False
# - - PUNCT HYPH punct - False False
# doped dope VERB VBN amod xxxx True False
# SnO2 sno2 NOUN NN pobj XxXd False False
# ( ( PUNCT -LRB- punct ( False False
# FTO fto PROPN NNP appos XXX True False
# , , PUNCT , punct , False False
# Pilkington pilkington PROPN NNP conj Xxxxx True False
# , , PUNCT , punct , False False
# TEC8 tec8 PROPN NNP appos XXXd False False
# ) ) PUNCT -RRB- punct ) False False
# substrate substrate VERB VBP advcl xxxx True False
# by by ADP IN agent xx True True
# spray spray NOUN NN compound xxxx True False
# pyrolysis pyrolysis NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# using use VERB VBG advcl xxxx True True
# a a DET DT det x True True
# 20 20 NUM CD nummod dd False False
# mM mm NOUN NN compound xX True False
# titanium titanium NOUN NN compound xxxx True False
# diisopropoxide diisopropoxide NOUN NN compound xxxx True False
# bis(acetylacetonate bis(acetylacetonate NOUN NN nmod xxx(xxxx False False
# ) ) PUNCT -RRB- punct ) False False
# solution solution NOUN NN dobj xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# Aldrich aldrich PROPN NNP appos Xxxxx True False
# ) ) PUNCT -RRB- punct ) False False
# at at ADP IN prep xx True True
# 450 450 NUM CD nummod ddd False False
# ° ° NOUN NN compound ° False False
# C c PROPN NNP pobj X True False
# to to PART TO aux xx True True
# prevent prevent VERB VB xcomp xxxx True False
# direct direct ADJ JJ amod xxxx True False
# contact contact NOUN NN dobj xxxx True False
# between between ADP IN prep xxxx True True
# the the DET DT det xxx True True
# FTO fto PROPN NNP pobj XXX True False
# and and CCONJ CC cc xxx True True
# the the DET DT det xxx True True
# hole hole NOUN NN npadvmod xxxx True False
# - - PUNCT HYPH punct - False False
# conducting conduct VERB VBG amod xxxx True False
# layer layer NOUN NN conj xxxx True False
# . . PUNCT . punct . False False
# A a DET DT det X True False
# 200–300-nm 200–300-nm NUM CD nummod ddd–ddd-xx False False
# - - PUNCT HYPH punct - False False
# thick thick ADJ JJ amod xxxx True False
# mesoporous mesoporous ADJ JJ amod xxxx True False
# TiO2 tio2 NOUN NNS nmod XxXd False False
# ( ( PUNCT -LRB- punct ( False False
# particle particle NOUN NN compound xxxx True False
# size size NOUN NN nsubjpass xxxx True False
# : : PUNCT : punct : False False
# about about ADV RB quantmod xxxx True True
# 50 50 NUM CD nummod dd False False
# nm nm NUM CD appos xx True False
# , , PUNCT , punct , False False
# crystalline crystalline ADJ JJ amod xxxx True False
# phase phase NOUN NN appos xxxx True False
# : : PUNCT : punct : False False
# anatase anatase NOUN NN nmod xxxx True False
# ) ) PUNCT -RRB- punct ) False False
# film film NOUN NN nsubj xxxx True False
# was be VERB VBD auxpass xxx True True
# spin spin NOUN NN npadvmod xxxx True False
# - - PUNCT HYPH punct - False False
# coated coat VERB VBN ROOT xxxx True False
# onto onto ADP IN prep xxxx True True
# the the DET DT det xxx True True
# bl bl NUM CD compound xx True False
# - - PUNCT HYPH punct - False False
# TiO2/FTO tio2/fto VERB VBN compound XxXd/XXX False False
# substrate substrate NOUN NN pobj xxxx True False
# using use VERB VBG acl xxxx True True
# home home NOUN NN npadvmod xxxx True False
# - - PUNCT HYPH punct - False False
# made make VERB VBN amod xxxx True True
# pastes14 pastes14 NOUN NN dobj xxxxdd False False
# and and CCONJ CC cc xxx True True
# calcining calcine VERB VBG conj xxxx True False
# at at ADP IN prep xx True True
# 500 500 NUM CD nummod ddd False False
# ° ° NOUN NN compound ° False False
# C c PROPN NNP pobj X True False
# for for ADP IN prep xxx True True
# 1 1 NUM CD nummod d False False
# h h NOUN NN pobj x True False
# in in ADP IN prep xx True True
# air air NOUN NN pobj xxx True False
# to to PART TO aux xx True True
# remove remove VERB VB advcl xxxx True False
# organic organic ADJ JJ amod xxxx True False
# components component NOUN NNS dobj xxxx True False
# . . PUNCT . punct . False False
# CH3NH3I ch3nh3i NOUN NN ROOT XXdXXdX False False
# ( ( PUNCT -LRB- punct ( False False
# MAI mai PROPN NNP nsubjpass XXX True False
# ) ) PUNCT -RRB- punct ) False False
# and and CCONJ CC cc xxx True True
# CH3NH3Br ch3nh3br NOUN NNS conj XXdXXdXx False False
# ( ( PUNCT -LRB- punct ( False False
# MABr mabr NOUN NNS appos XXXx True False
# ) ) PUNCT -RRB- punct ) False False
# were be VERB VBD auxpass xxxx True True
# first first ADV RB advmod xxxx True True
# synthesized synthesize VERB VBN ROOT xxxx True False
# by by ADP IN prep xx True True
# reacting react VERB VBG pcomp xxxx True False
# 27.86 27.86 NUM CD nummod dd.dd False False
# ml ml PROPN NNP dobj xx True False
# CH3NH2 ch3nh2 PROPN NNP appos XXdXXd False False
# ( ( PUNCT -LRB- punct ( False False
# 40 40 NUM CD nummod dd False False
# % % NOUN NN appos % False False
# in in ADP IN prep xx True True
# methanol methanol NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# Junsei junsei PROPN NNP compound Xxxxx True False
# Chemical chemical PROPN NNP appos Xxxxx True False
# ) ) PUNCT -RRB- punct ) False False
# and and CCONJ CC cc xxx True True
# 30 30 NUM CD nummod dd False False
# ml ml NOUN NN compound xx True False
# HI hi PROPN NNP conj XX True False
# ( ( PUNCT -LRB- punct ( False False
# 57 57 NUM CD nummod dd False False
# wt% wt% PROPN NNP appos xx% False False
# in in ADP IN prep xx True True
# water water NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# Aldrich aldrich PROPN NNP appos Xxxxx True False
# ) ) PUNCT -RRB- punct ) False False
# or or CCONJ CC cc xx True True
# 44 44 NUM CD nummod dd False False
# ml ml PROPN NNP conj xx True False
# HBr hbr NOUN NNS appos XXx True False
# ( ( PUNCT -LRB- punct ( False False
# 48 48 NUM CD nummod dd False False
# wt% wt% PROPN NNP appos xx% False False
# in in ADP IN prep xx True True
# water water NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# Aldrich aldrich PROPN NNP npadvmod Xxxxx True False
# ) ) PUNCT -RRB- punct ) False False
# in in ADP IN prep xx True True
# a a DET DT det x True True
# 250 250 NUM CD nummod ddd False False
# ml ml ADJ JJ nmod xx True False
# round round ADJ JJ amod xxxx True False
# - - PUNCT HYPH punct - False False
# bottom bottom NOUN NN compound xxxx True True
# flask flask NOUN NN pobj xxxx True False
# at at ADP IN prep xx True True
# 0 0 NUM CD pobj d False False
# ° ° NOUN NN ROOT ° False False
# C c NOUN NN dobj X True False
# for for ADP IN prep xxx True True
# 4 4 NUM CD nummod d False False
# h h NOUN NN pobj x True False
# with with ADP IN prep xxxx True True
# stirring stirring NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# respectively respectively ADV RB advmod xxxx True False
# . . PUNCT . punct . False False
# The the DET DT det Xxx True False
# precipitate precipitate NOUN NN nsubjpass xxxx True False
# was be VERB VBD auxpass xxx True True
# recovered recover VERB VBN ROOT xxxx True False
# by by ADP IN agent xx True True
# evaporation evaporation NOUN NN pobj xxxx True False
# at at ADP IN prep xx True True
# 55 55 NUM CD nummod dd False False
# ° ° NOUN NN compound ° False False
# C c PROPN NNP pobj X True False
# for for ADP IN prep xxx True True
# 1 1 NUM CD nummod d False False
# h. h. NOUN NN compound x. False False
# MAI mai PROPN NNP pobj XXX True False
# and and CCONJ CC cc xxx True True
# MABr mabr NOUN NNS conj XXXx True False
# were be VERB VBD auxpass xxxx True True
# dissolved dissolve VERB VBN conj xxxx True False
# in in ADP IN prep xx True True
# ethanol ethanol NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# recrystallized recrystalliz VERB VBN conj xxxx True False
# from from ADP IN prep xxxx True True
# diethyl diethyl NUM CD compound xxxx True False
# ether ether NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True True
# dried dry VERB VBD conj xxxx True False
# at at ADP IN prep xx True True
# 60 60 NUM CD nummod dd False False
# ° ° NOUN NN compound ° False False
# C c PROPN NNP pobj X True False
# in in ADP IN prep xx True True
# a a DET DT det x True True
# vacuum vacuum NOUN NN pobj xxxx True False
# oven oven NOUN NN acl xxxx True False
# for for ADP IN prep xxx True True
# 24 24 NUM CD nummod dd False False
# h. h. NOUN NN pobj x. False False
# The the DET DT det Xxx True False
# prepared prepared ADJ JJ amod xxxx True False
# MAI mai NOUN NN ROOT XXX True False
# and and CCONJ CC cc xxx True True
# MABr mabr NOUN NNS compound XXXx True False
# powders powder NOUN NNS conj xxxx True False
# , , PUNCT , punct , False False
# PbI2 pbi2 PROPN NNP conj XxXd False False
# ( ( PUNCT -LRB- punct ( False False
# Aldrich aldrich PROPN NNP appos Xxxxx True False
# ) ) PUNCT -RRB- punct ) False False
# and and CCONJ CC cc xxx True True
# PbBr2 pbbr2 PROPN NNP conj XxXxd False False
# ( ( PUNCT -LRB- punct ( False False
# Aldrich aldrich PROPN NNP nsubj Xxxxx True False
# ) ) PUNCT -RRB- punct ) False False
# for for ADP IN prep xxx True True
# 0.8 0.8 NUM CD nummod d.d False False
# M m PROPN NNP compound X True False
# MAPb(I1 mapb(i1 PROPN NNP pobj XXXx(Xd False False
# − − ADP IN ROOT − False False
# xBrx)3 xbrx)3 NOUN NN nmod xXxx)d False False
# ( ( PUNCT -LRB- punct ( False False
# x x SYM SYM intj x True False
#     SPACE     False False
# = = SYM SYM punct = False False
#     SPACE     False False
# 0.1–0.15 0.1–0.15 NUM CD nmod d.d–d.dd False False
# ) ) PUNCT -RRB- punct ) False False
# solution solution NOUN NN dobj xxxx True False
# were be VERB VBD auxpass xxxx True True
# stirred stir VERB VBN advcl xxxx True False
# in in ADP IN prep xx True True
# a a DET DT det x True True
# mixture mixture NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# GBL gbl PROPN NNP pobj XXX True False
# and and CCONJ CC cc xxx True True
# DMSO dmso PROPN NNP conj XXXX True False
# ( ( PUNCT -LRB- punct ( False False
# 7:3 7:3 NUM CD appos d:d False False
# v v NOUN NN intj x True False
# / / SYM SYM punct / False False
# v v PUNCT LS pobj x True False
# ) ) PUNCT -RRB- punct ) False False
# at at ADP IN prep xx True True
# 60 60 NUM CD nummod dd False False
# ° ° NOUN NN compound ° False False
# C c NOUN NN pobj X True False
# for for ADP IN prep xxx True True
# 12 12 NUM CD nummod dd False False
# h. h. NOUN NN pobj x. False False
# The the DET DT det Xxx True False
# resulting result VERB VBG amod xxxx True False
# solution solution NOUN NN nsubjpass xxxx True False
# was be VERB VBD auxpass xxx True True
# coated coat VERB VBN ROOT xxxx True False
# onto onto ADP IN prep xxxx True True
# the the DET DT det xxx True True
# mp mp PROPN NNP nmod xx True False
# - - PUNCT HYPH punct - False False
# TiO2/bl tio2/bl NOUN NN appos XxXd/xx False False
# - - PUNCT HYPH punct - False False
# TiO2/FTO tio2/fto VERB VBN compound XxXd/XXX False False
# substrate substrate NOUN NN pobj xxxx True False
# by by ADP IN agent xx True True
# a a DET DT det x True True
# consecutive consecutive ADJ JJ amod xxxx True False
# two two NUM CD nummod xxx True True
# - - PUNCT HYPH punct - False False
# step step NOUN NN nmod xxxx True False
# spin spin NOUN NN compound xxxx True False
# - - PUNCT HYPH punct - False False
# coating coat VERB VBG amod xxxx True False
# process process NOUN NN pobj xxxx True False
# at at ADP IN prep xx True True
# 1,000 1,000 NUM CD nummod d,ddd False False
# and and CCONJ CC cc xxx True True
# 5,000 5,000 NUM CD conj d,ddd False False
# r.p.m r.p.m NOUN NN pobj x.x.x False False
# for for ADP IN prep xxx True True
# 10 10 NUM CD nummod dd False False
# and and CCONJ CC cc xxx True True
# 20 20 NUM CD conj dd False False
# s s NOUN NNS pobj x True False
# , , PUNCT , punct , False False
# respectively respectively ADV RB advmod xxxx True False
# . . PUNCT . punct . False False
# During during ADP IN prep Xxxxx True False
# the the DET DT det xxx True True
# second second ADJ JJ amod xxxx True False
# spin spin NOUN NN npadvmod xxxx True False
# - - PUNCT HYPH punct - False False
# coating coat VERB VBG amod xxxx True False
# step step NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# the the DET DT det xxx True True
# substrate substrate NOUN NN amod xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# around around ADV RB advmod xxxx True True
# 1 1 NUM CD nummod d False False
# cm cm NOUN NN nsubjpass xx True False
# × × NOUN NNS intj × False False
# 1 1 NUM CD nummod d False False
# cm cm NOUN NN appos xx True False
# ) ) PUNCT -RRB- punct ) False False
# was be VERB VBD auxpass xxx True True
# treated treat VERB VBN ROOT xxxx True False
# with with ADP IN prep xxxx True True
# toluene toluene NOUN NN compound xxxx True False
# drop drop NOUN NN compound xxxx True False
# - - PUNCT HYPH punct - False False
# casting casting NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# A a DET DT det X True False
# detailed detailed ADJ JJ amod xxxx True False
# time time NOUN NN compound xxxx True False
# - - PUNCT HYPH punct - False False
# rotation rotation NOUN NN compound xxxx True False
# profile profile NOUN NN nsubjpass xxxx True False
# for for ADP IN prep xxx True True
# the the DET DT det xxx True True
# spin spin NOUN NN compound xxxx True False
# - - PUNCT HYPH punct - False False
# coating coating NOUN NN pobj xxxx True False
# is be VERB VBZ auxpass xx True True
# represented represent VERB VBN ROOT xxxx True False
# in in ADP IN prep xx True True
# Supplementary supplementary PROPN NNP compound Xxxxx True False
# Fig fig PROPN NNP pobj Xxx True False
# . . PUNCT . punct . False False
# 1c 1c NUM CD ROOT dx False False
# . . PUNCT . punct . False False
# The the DET DT det Xxx True False
# substrate substrate NOUN NN nsubjpass xxxx True False
# was be VERB VBD auxpass xxx True True
# dried dry VERB VBN ROOT xxxx True False
# on on ADP IN prep xx True True
# a a DET DT det x True True
# hot hot ADJ JJ amod xxx True False
# plate plate NOUN NN pobj xxxx True False
# at at ADP IN prep xx True True
# 100 100 NUM CD nummod ddd False False
# ° ° NOUN NN compound ° False False
# C c PROPN NNP pobj X True False
# for for ADP IN prep xxx True True
# 10 10 NUM CD nummod dd False False
# min min NOUN NN pobj xxx True False
# . . PUNCT . punct . False False
# A a DET DT det X True False
# solution solution NOUN NN nsubj xxxx True False
# of of ADP IN prep xx True True
# poly(triarylamine poly(triarylamine NOUN NN pobj xxxx(xxxx False False
# ) ) PUNCT -RRB- punct ) False False
# ( ( PUNCT -LRB- punct ( False False
# 15 15 NUM CD nummod dd False False
# mg mg NOUN NN appos xx True False
# , , PUNCT , punct , False False
# PTAA ptaa PROPN NNP conj XXXX True False
# , , PUNCT , punct , False False
# EM em PROPN NNP compound XX True False
# Index index PROPN NNP conj Xxxxx True False
# , , PUNCT , punct , False False
# Mw mw PROPN NNP conj Xx True False
#     SPACE     False False
# = = SYM SYM punct = False False
#     SPACE     False False
# 17,500 17,500 NUM CD nummod dd,ddd False False
# g g DET DT appos x True False
# mol−1 mol−1 NOUN NN appos xxx−d False False
# ) ) PUNCT -RRB- punct ) False False
# in in ADP IN prep xx True True
# toluene toluene NOUN NN pobj xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 1.5 1.5 NUM CD nummod d.d False False
# ml ml NOUN NN appos xx True False
# ) ) PUNCT -RRB- punct ) False False
# was be VERB VBD ROOT xxx True True
# mixed mix VERB VBN acomp xxxx True False
# with with ADP IN prep xxxx True True
# 15 15 NUM CD nummod dd False False
# μl μl ADP IN pobj xx True False
# of of ADP IN prep xx True True
# a a DET DT det x True True
# solution solution NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# lithium lithium NOUN NN compound xxxx True False
# bistrifluoromethanesulphonimidate bistrifluoromethanesulphonimidate NOUN NN pobj xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 170 170 NUM CD nummod ddd False False
# mg mg NOUN NN appos xx True False
# ) ) PUNCT -RRB- punct ) False False
# in in ADP IN prep xx True True
# acetonitrile acetonitrile NOUN NN amod xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 1 1 NUM CD nummod d False False
# ml ml NOUN NN pobj xx True False
# ) ) PUNCT -RRB- punct ) False False
# and and CCONJ CC cc xxx True True
# 7.5 7.5 NUM CD nummod d.d False False
# μl μl ADP IN nsubj xx True False
# 4-tert 4-tert ADJ JJ amod d-xxxx False False
# - - PUNCT HYPH punct - False False
# butylpyridine butylpyridine NOUN NN amod xxxx True False
# and and CCONJ CC cc xxx True True
# spin spin NOUN NN advmod xxxx True False
# - - PUNCT HYPH punct - False False
# coated coat VERB VBN conj xxxx True False
# on on ADP IN prep xx True True
# the the DET DT det xxx True True
# MAPb(I1 mapb(i1 PROPN NNP pobj XXXx(Xd False False
# − − ADP IN conj − False False
# xBrx)3 xbrx)3 NOUN NN dobj xXxx)d False False
# ( ( PUNCT -LRB- punct ( False False
# x x SYM SYM punct x True False
#     SPACE     False False
# = = SYM SYM punct = False False
#     SPACE     False False
# 0.1–0.15)/mp 0.1–0.15)/mp NUM CD nummod d.d–d.dd)/xx False False
# - - PUNCT HYPH punct - False False
# TiO2/bl tio2/bl NOUN NN compound XxXd/xx False False
# - - PUNCT HYPH punct - False False
# TiO2/FTO tio2/fto PROPN NNP parataxis XxXd/XXX False False
# substrate substrate NOUN NN ROOT xxxx True False
# at at ADP IN prep xx True True
# 3,000 3,000 NUM CD nummod d,ddd False False
# r.p.m r.p.m NOUN NN pobj x.x.x False False
# for for ADP IN prep xxx True True
# 30 30 NUM CD nummod dd False False
# s. s. NOUN NN pobj x. False False
# Finally finally ADV RB advmod Xxxxx True False
# , , PUNCT , punct , False False
# a a DET DT det x True True
# Au au PROPN NNP compound Xx True False
# counterelectrode counterelectrode NOUN NN nsubjpass xxxx True False
# was be VERB VBD auxpass xxx True True
# deposited deposit VERB VBN ROOT xxxx True False
# by by ADP IN agent xx True True
# thermal thermal ADJ JJ amod xxxx True False
# evaporation evaporation NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# The the DET DT det Xxx True False
# active active ADJ JJ amod xxxx True False
# area area NOUN NN nsubjpass xxxx True False
# of of ADP IN prep xx True True
# this this DET DT det xxxx True True
# electrode electrode NOUN NN pobj xxxx True False
# was be VERB VBD auxpass xxx True True
# fixed fix VERB VBN ROOT xxxx True False
# at at ADP IN prep xx True True
# 0.16 0.16 NUM CD nummod d.dd False False
# cm2 cm2 NOUN NN pobj xxd False False
# . . PUNCT . punct . False False
