# %% [markdown]
# ## Initialization

# %%
import spacy
import pkgtesting

# %% [markdown]
# ## Testing
#
# Basic testing copied from spaCy documentation.

# %%
nlp = spacy.load('en')
doc = nlp(u"This is a sentence.")
print([(w.text, w.pos_) for w in doc])
# Out:
# [('This', 'DET'), ('is', 'VERB'), ('a', 'DET'), ('sentence', 'NOUN'), ('.', 'PUNCT')]

# %% [markdown]
# ## Testing with Angewandte paper

# %%
angew = pkgtesting.convert_pdf_to_txt('/home/christinehc/downloads/anie.201406466.pdf')

# %%
#angew
angew_nlp = nlp(angew)
print([(w.text, w.pos_) for w in angew_nlp])
# Out:
# [('Angewandte', 'ADP'), ('\n\n', 'SPACE'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('Communications', 'NOUN'), ('\n\n', 'SPACE'), ('Perovskite', 'PROPN'), ('Solar', 'PROPN'), ('Cells', 'PROPN'), ('\n\n', 'SPACE'), ('DOI', 'PROPN'), (':', 'PUNCT'), ('10.1002/anie.201406466', 'NUM'), ('\n\n', 'SPACE'), ('A', 'DET'), ('Layered', 'PROPN'), ('Hybrid', 'PROPN'), ('Perovskite', 'PROPN'), ('Solar', 'PROPN'), ('-', 'PUNCT'), ('Cell', 'PROPN'), ('Absorber', 'PROPN'), ('with', 'ADP'), ('Enhanced', 'PROPN'), ('\n', 'SPACE'), ('Moisture', 'PROPN'), ('Stability', 'PROPN'), ('*', 'PUNCT'), ('*', 'PUNCT'), ('\n', 'SPACE'), ('Ian', 'PROPN'), ('C.', 'PROPN'), ('Smith', 'PROPN'), (',', 'PUNCT'), ('Eric', 'PROPN'), ('T.', 'PROPN'), ('Hoke', 'PROPN'), (',', 'PUNCT'), ('Diego', 'PROPN'), ('Solis', 'PROPN'), ('-', 'PUNCT'), ('Ibarra', 'PROPN'), (',', 'PUNCT'), ('Michael', 'PROPN'), ('D.', 'PROPN'), ('McGehee', 'PROPN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('\n', 'SPACE'), ('Hemamala', 'PROPN'), ('I.', 'PROPN'), (
# ...
